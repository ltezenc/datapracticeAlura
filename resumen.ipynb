# %% [markdown]
# # Informe Final
# # 📝 Introducción
# En el presente informe se analizan los resultados de las cuatro tiendas de la cadena Alura Store con el objetivo de determinar cuál es la menos eficiente y, por tanto, la que debería vender el Sr. Juan para financiar un nuevo emprendimiento. Para este análisis se consideraron los ingresos totales, las categorías y productos más vendidos, la calificación promedio de los clientes, y el costo promedio de envío en cada tienda.
#
# # Desarrollo del análisis
# # 💰 1. Ingresos Totales por Tienda
# Se calcularon los ingresos totales de cada tienda:
# ![totales por tienda.png](data:image/png;base64,...)
#
# **Conclusión parcial:** La tienda con ingresos más bajos es la menos rentable.

# %% [markdown]
# # Categorías y Productos más Vendidos
# Para comprender qué impulsa las ventas, se obtuvieron las categorías más populares por tienda y el top 3 de productos. Por ejemplo:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# Se generaron gráficos circulares para visualizar qué tiendas tienen mayor dependencia en pocos productos, lo que puede ser un factor de riesgo.

# %% [markdown]
# # Calificación Promedio por Tienda
# Se analizó la satisfacción de los clientes mediante la calificación promedio:
#
# ![image.png](data:image/png;base64,...)
#
# **Conclusión parcial**: Una calificación baja es un indicador de que esa tienda presenta problemas en calidad de servicio o producto.

# %% [markdown]
# #Costo de Envío Promedio
# Se comparó el costo de envío promedio entre tiendas, encontrándose que:
#
# ![image.png](data:image/png;base64,...)
#
# Tiendas con costo elevado tienen menos margen de ganancia y menor competitividad.

# %% [markdown]
# #Conclusión y Recomendación
# Tras analizar los cuatro criterios clave, la Tienda 4 es la menos eficiente. Presenta los ingresos totales más bajos, calificación promedio baja.
#
# Por ello, se recomienda que el Sr. Juan venda la Tienda 4 y destine los ingresos a su nuevo proyecto, manteniendo las tiendas más eficientes y mejor posicionadas.
#
# #Recomendacion Adicional
# Se ha detectado que los ingresos no van de la mano con la calificacion
# ![image.png](data:image/png;base64,...)
#
# Se debe analizar las causas de estos motivos como:
# 1.  **Factores de Ubicación y Demografía:**
# 2. **Variedad de Productos y Nicho de Mercado:**
# 3. **Ver si el personal esta capacitado para atender la demanda de ventas**
# 4. **Calidad y estado de los productos**
# 5. **Demora en las entregas**
